# %%
from pydantic import BaseModel, Field
from typing import Literal

class AnswerEvaluation(BaseModel):
    reasoning: str = Field(
        description="Reasoning about the quality of the answer."
    )
    score: Literal["good", "bad"] = Field(
        description="'good' if the answer is correct and complete, 'bad' otherwise."
    )

# %%
aqa_judge_instructions = """
You are an expert evaluator. You will be given:
1. A question from a student
2. The original answer from the FAQ (ground truth)
3. An answer generated by an AI assistant

Your task is to decide if the AI answer is semantically equivalent to
the original answer.

Rules:
- The AI answer does NOT need to be word-for-word identical
- It should convey The same key information
- Extra detail is fine as long as The core answer is correct
- Mark 'bad' only if the AI answer is wrong or misses the key point

Be fair and focus on correctness, not style.
""".strip()

# %%
aqa_judge_prompt = """
Question:
{question}

Original Answer (ground truth):
{answer_orig}

AI Answer:
{answer_llm}
""".strip()

# %%
from dotenv import load_dotenv
from openai import OpenAI
from evaluation_utils import calc_price, calc_total_price, llm_structured_retry, map_progress

load_dotenv()
openai_client = OpenAI()

# %%
import pandas as pd

df_answers = pd.read_csv("data/rag-answers-new.csv")
answers = df_answers.to_dict(orient="records")

# %%
rec = answers[0]
rec
# Out:
# {'question': 'Is it okay to join the course late if I just found it now?',
#  'answer_llm': "('Yes, you can still join the course late if you just discovered it. If you want a certificate, make sure to submit your project while submissions are still being accepted.', 0)",
#  'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#  'document': '74eb249bbf'}

# %%
prompt = aqa_judge_prompt.format(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)
print(prompt)
# Out:
# Question:
# Is it okay to join the course late if I just found it now?
#
# Original Answer (ground truth):
# Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.
#
# AI Answer:
# ('Yes, you can still join the course late if you just discovered it. If you want a certificate, make sure to submit your project while submissions are still being accepted.', 0)

# %%
eval_result, usage = llm_structured_retry(
    openai_client,
    aqa_judge_instructions,
    prompt,
    AnswerEvaluation,
)

eval_result
# Out:
# AnswerEvaluation(reasoning='The AI answer conveys the same meaning as the ground truth: late joining is allowed, and certificate eligibility requires submitting the project before submissions close. The extra tuple formatting does not change the semantic content.', score='good')

# %%
calc_price(usage)
# Out:
# {'input_cost': 0.000228, 'output_cost': 0.0002475, 'total_cost': 0.0004755}

# %%
def evaluate_aqa(question, answer_orig, answer_llm, model="gpt-5.4-mini"):
    prompt = aqa_judge_prompt.format(
        question=question,
        answer_orig=answer_orig,
        answer_llm=answer_llm
    )

    result, usage = llm_structured_retry(
        openai_client,
        aqa_judge_instructions,
        prompt,
        AnswerEvaluation,
        model=model,
    )

    return result, usage

# %%
eval_result, usage = evaluate_aqa(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)

eval_result
# Out:
# AnswerEvaluation(reasoning='The AI answer preserves the core meaning of the ground truth: late joining is allowed, but certificate eligibility depends on submitting the project before submissions close. The extra tuple-like formatting and the 0 do not change the semantic content.', score='good')

# %%
def judge_record(rec):
    eval_result, usage = evaluate_aqa(
        question=rec["question"],
        answer_orig=rec["answer_orig"],
        answer_llm=rec["answer_llm"]
    )

    result = {
        "question": rec["question"],
        "document": rec["document"],
        "score": eval_result.score,
        "reasoning": eval_result.reasoning,
    }

    return result, usage

# %%
from concurrent.futures import ThreadPoolExecutor

with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, answers, judge_record)
# Out:
#   0%|          | 0/315 [00:00<?, ?it/s]

# %%
results[10]
# Out:
# ({'question': 'How do I join the Office Hours or live workshop if I don’t have the Zoom link?',
#   'document': '489dd1c9d9',
#   'score': 'good',
#   'reasoning': 'The AI answer matches the ground truth: it states that the Zoom link is only for instructors/presenters/TAs, tells students to join via YouTube Live, mentions the announcements channel on Telegram and Slack, the DataTalksClub YouTube channel, and using Slido instead of chat for questions. No key information is missing or incorrect.'},
#  ResponseUsage(input_tokens=436, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=85, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=521))

# %%
evaluations = []
usages = []

for evaluation, usage in results:
    evaluations.append(evaluation)
    usages.append(usage)

# %%
calc_total_price(usages)
# Out:
# 0.20928224999999992

# %%
df_eval = pd.DataFrame(evaluations)

# %%
df_eval.head()
# Out:
#                                             question    document score  \
# 0  Is it okay to join the course late if I just f...  74eb249bbf  good
# 1  Can I still take this course even if I missed ...  74eb249bbf  good
# 2  If I join after the course has already started...  74eb249bbf  good
# 3  Do I need to submit my project before submissi...  74eb249bbf  good
# 4  I’m a bit late to the course—what do I need to...  74eb249bbf  good
#
#                                            reasoning
# 0  The AI answer conveys the same meaning as the ...
# 1  The AI answer preserves the key point: yes, th...
# 2  The AI answer preserves the key meaning of the...
# 3  The AI answer matches the ground truth: it say...
# 4  The AI answer captures the key point that a la...

# %%
df_eval.score.value_counts()
# Out:
# score
# good    293
# bad      22
# Name: count, dtype: int64

# %%
df_eval.score.value_counts(normalize=True)
# Out:
# score
# good    0.930159
# bad     0.069841
# Name: proportion, dtype: float64

# %%
df_eval[df_eval["score"] == "bad"].head()
# Out:
#                                              question    document score  \
# 27  What do I actually need to pass in order to ge...  9f689c185f   bad
# 33  How will I know when a module is actually read...  96286b4be4   bad
# 39    Can you tell me when the course is coming back?  bd31146b0e   bad
# 62  I added billing but still get an insufficient_...  152af39a53   bad
# 63  Which model should I use in chat.completions.c...  152af39a53   bad
#
#                                             reasoning
# 27  The AI answer correctly states that passing th...
# 33  The AI answer does not convey the ground truth...
# 39  The ground truth states the course is coming b...
# 62  The AI answer captures only one minor part of ...
# 63  The ground truth says the issue is insufficien...

# %%
df_eval.to_csv("data/rag-evaluations-new.csv", index=False)
